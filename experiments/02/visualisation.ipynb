# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from m2_cw.data import visualise_forecasts


file_paths = [ file for file in Path.cwd().iterdir() if "forecast" in str(file) ]
file_path = file_paths[0]

visualise_forecasts(file_path, plots_per_row=20)
# Out:
# Rejected: series_id,forecast
